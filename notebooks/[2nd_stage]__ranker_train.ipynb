# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os
import sys

import random

sys.path.append('/home/juravlik/PycharmProjects/kaggle_hnm_recsys/')

from lightgbm import LGBMRanker

from scripts.metrics.mapk import mapk

pd.set_option('display.max_columns', 500)

import warnings
warnings.filterwarnings("ignore")

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
path_to_set = '/home/juravlik/PycharmProjects/kaggle_hnm_recsys/data/train_set_and_labels/test_4/'
selected_customers = None #list(pd.read_parquet('/home/juravlik/PycharmProjects/kaggle_hnm_recsys/data/train_set_and_labels/test_2/week_0__part_0.parquet')['customer_id'].unique())
weeks_for_train = [2, 3, 4, 5, 6, 7, 8]
week_for_test = 1

# %%
for i in weeks_for_train:
    if i == weeks_for_train[0]:
        df_train = pd.read_parquet(os.path.join(path_to_set, 'week_{}.parquet'.format(i)))
    else:
        df_train = pd.concat([df_train,
                              pd.read_parquet(os.path.join(path_to_set, 'week_{}.parquet'.format(i)))],
                              ignore_index=True)
    
    if selected_customers:
        df_train = df_train[df_train['customer_id'].isin(selected_customers)]

# %%
df_train = reduce_mem_usage(df_train)
# Out:
# Memory usage of dataframe is 5676.01 MB
# Memory usage after optimization is: 4881.76 MB
# Decreased by 14.0%

# %%
# df_train.fillna(-1000, inplace=True)

# %%
# sample_weight_dict = {2: 1, 3: 0.7, 4: 0.7, 5: 0.7, 6: 0.4, 7: 0.4, 8: 0.3}
# sample_weight_dict = {2: 1, 3: 0.8, 4: 0.7, 5: 0.65, 6: 0.5, 7: 0.4, 8: 0.3}
# sample_weight_dict = {2: 1, 3: 1, 4: 1, 5: 1, 6: 0.5, 7: 0.5, 8: 0.5}


# sample_weights = df_train['weeks_before_sub'].apply(lambda x: sample_weight_dict[x])

# %%
features = list(df_train.columns)
features.remove('article_id')
features.remove('customer_id')
features.remove('weeks_before_sub')
features.remove('label')

# %%
ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    eval_at=12,
    boosting_type="gbdt", #gbdt #goss
    
    force_col_wise=True,
    num_leaves=40, #31 #40
    max_depth=-1, #10 #-1
    learning_rate=0.1, #0.1
    
#     reg_lambda=0.1, #0 #0.3
    
    importance_type='split',
    
    min_split_gain=0, #0 #0.7
    
    colsample_bytree=1, #1
    
    n_estimators=200, #100 #150
    
    random_state=42,
    verbose=1
)

# %%
ranker = ranker.fit(
    X=df_train[features],
    y=df_train[['label']],
#     sample_weight=sample_weights,
    group=df_train.groupby(['customer_id'])['article_id'].count().values
)

# %%
del df_train

df_test = pd.read_parquet(os.path.join(path_to_set, 'week_{}.parquet'.format(week_for_test)))
   
labels = pd.read_parquet('/home/juravlik/PycharmProjects/kaggle_hnm_recsys/data/ranker_train_labels/labels_{}.parquet'.format(week_for_test))

# %%
df_test = reduce_mem_usage(df_test)
# Out:
# Memory usage of dataframe is 666.86 MB
# Memory usage after optimization is: 573.54 MB
# Decreased by 14.0%

# %%
# df_test.fillna(-1000, inplace=True)

# %%
df_test['predict'] = ranker.predict(
    df_test[features]
)

# %%
df_test = df_test.sort_values(['customer_id', 'predict'], ascending=False).groupby('customer_id').head(12)

# %%
df_test
# Out:
#          customer_id  article_id  weeks_before_sub  score_ARulesRecommender  \
# 498353       1371960      102628                 1                      NaN
# 231479       1371960       66500                 1                      NaN
# 442966       1371960       99010                 1                      NaN
# 578545       1371960       80932                 1                      NaN
# 661618       1371960       97246                 1                      NaN
# ...              ...         ...               ...                      ...
# 2236282           80       94696                 1                      NaN
# 857289            80      104045                 1                      NaN
# 1876455           80       67543                 1                      NaN
# 2037551           80       53893                 1                      NaN
# 1823206           80      103793                 1                      NaN
#
#          score_GruRecommender  score_ItemsPurchasedTogetherRecommender  \
# 498353                    NaN                                 0.916504
# 231479               6.953125                                 1.000000
# 442966                    NaN                                 0.958496
# 578545                    NaN                                 0.875000
# 661618                    NaN                                 0.791504
# ...                       ...                                      ...
# 2236282                   NaN                                      NaN
# 857289                    NaN                                 0.666504
# 1876455                   NaN                                      NaN
# 2037551                   NaN                                      NaN
# 1823206                   NaN                                      NaN
#
#          score_KaggleCustomerAgeRecommender  \
# 498353                             0.916504
# 231479                             1.000000
# 442966                             0.958496
# 578545                             0.875000
# 661618                             0.791504
# ...                                     ...
# 2236282                                 NaN
# 857289                                  NaN
# 1876455                                 NaN
# 2037551                                 NaN
# 1823206                                 NaN
#
#          score_KaggleExponentialDecayRecommender  \
# 498353                                  1.000000
# 231479                                  0.958496
# 442966                                  0.916504
# 578545                                  0.750000
# 661618                                  0.833496
# ...                                          ...
# 2236282                                      NaN
# 857289                                  0.750000
# 1876455                                 0.541504
# 2037551                                      NaN
# 1823206                                 0.583496
#
#          score_KaggleTrendingRecommender  score_KMeansRecommender  \
# 498353                          0.333252            108770.679688
# 231479                          1.000000            150140.843750
# 442966                          0.500000            150140.843750
# 578545                          0.142822             54385.339844
# 661618                          0.199951             54385.339844
# ...                                  ...                      ...
# 2236282                              NaN                      NaN
# 857289                               NaN                      NaN
# 1876455                              NaN                      NaN
# 2037551                         0.090881                      NaN
# 1823206                              NaN                      NaN
#
#          score_LastPurchasesPopularity  score_LightFMRecommender  \
# 498353                        1.000000                   -376.75
# 231479                        0.500000                   -377.00
# 442966                        0.333252                       NaN
# 578545                        0.142822                   -377.25
# 661618                        0.199951                   -376.75
# ...                                ...                       ...
# 2236282                       0.090881                       NaN
# 857289                        0.142822                       NaN
# 1876455                            NaN                       NaN
# 2037551                            NaN                       NaN
# 1823206                            NaN                       NaN
#
#          score_PopularByGroupsRecommender  score_SVDRecommender  colour_Beige  \
# 498353                                NaN              0.969727           0.0
# 231479                                NaN              0.969727           1.0
# 442966                                NaN              0.969727           0.0
# 578545                                NaN              0.969727           0.0
# 661618                                NaN              0.969727           0.0
# ...                                   ...                   ...           ...
# 2236282                               NaN                   NaN           0.0
# 857289                                NaN              0.125000           0.0
# 1876455                               NaN              0.090881           0.0
# 2037551                               NaN                   NaN           0.0
# 1823206                               NaN              0.083313           0.0
#
#          colour_Black  colour_Blue  colour_Bluish Green  colour_Brown  \
# 498353            1.0          0.0                  0.0           0.0
# 231479            0.0          0.0                  0.0           0.0
# 442966            0.0          0.0                  0.0           0.0
# 578545            0.0          0.0                  0.0           0.0
# 661618            0.0          0.0                  0.0           0.0
# ...               ...          ...                  ...           ...
# 1823206                                     50
#
#          article__num_days_from_last_purchase  \
# 498353                                      0
# 231479                                      1
# 442966                                      0
# 578545                                      0
# 661618                                      0
# ...                                       ...
# 2236282                                     0
# 857289                                      0
# 1876455                                     0
# 2037551                                     0
# 1823206                                     0
#
#          article__num_purchased_customers  \
# 498353                                410
# 231479                               2353
# 442966                                 87
# 578545                                226
# 661618                                402
# ...                                   ...
# 2236282                               764
# 857289                               3241
# 1876455                              2570
# 2037551                             34802
# 1823206                              2621
#
#          article__num_unique_purchased_customers  \
# 498353                                       324
# 231479                                      2129
# 442966                                        79
# 578545                                       200
# 661618                                       380
# ...                                          ...
# 2236282                                      695
# 857289                                      2855
# 1876455                                     2051
# 2037551                                    25320
# 1823206                                     2274
#
#          article__num_purchased_customers_last90days  \
# 498353                                           410
# 231479                                           216
# 442966                                            87
# 578545                                           226
# 661618                                           402
# ...                                              ...
# 2236282                                          764
# 857289                                          3241
# 1876455                                         2570
# 2037551                                         2345
# 1823206                                         2621
#
#          article__num_unique_purchased_customers_last90days  \
# 498353                                                 324
# 231479                                                 187
# 442966                                                  79
# 578545                                                 200
# 661618                                                 380
# ...                                                    ...
# 2236282                                                695
# 857289                                                2855
# 1876455                                               2051
# 2037551                                               2052
# 1823206                                               2274
#
#          article__num_purchased_customers_last30days  \
# 498353                                           410
# 231479                                           115
# 442966                                            87
# 578545                                           226
# 661618                                           401
# ...                                              ...
# 2236282                                          764
# 857289                                          2487
# 1876455                                         2419
# 2037551                                          876
# 1823206                                         2478
#
#          article__num_unique_purchased_customers_last30days  \
# 498353                                                 324
# 231479                                                  98
# 442966                                                  79
# 578545                                                 200
# 661618                                                 379
# ...                                                    ...
# 2236282                                                695
# 857289                                                2204
# 1876455                                               1934
# 2037551                                                788
# 1823206                                               2160
#
#          article__num_purchased_customers_last7days  \
# 498353                                           68
# 231479                                           26
# 442966                                           60
# 578545                                          167
# 661618                                           89
# ...                                             ...
# 2236282                                         552
# 857289                                          616
# 1876455                                         522
# 2037551                                         388
# 1823206                                         519
#
#          article__num_unique_purchased_customers_last7days  \
# 498353                                                  59
# 231479                                                  24
# 442966                                                  55
# 578545                                                 150
# 661618                                                  84
# ...                                                    ...
# 2236282                                                492
# 857289                                                 559
# 1876455                                                444
# 2037551                                                336
# 1823206                                                481
#
#          article__num_purchased_customers_last1days  \
# 498353                                           11
# 231479                                            2
# 442966                                            8
# 578545                                           23
# 661618                                           12
# ...                                             ...
# 2236282                                         106
# 857289                                           70
# 1876455                                          87
# 2037551                                          15
# 1823206                                          76
#
#          article__num_unique_purchased_customers_last1days  \
# 498353                                                  10
# 231479                                                   2
# 442966                                                   7
# 578545                                                  18
# 661618                                                  12
# ...                                                    ...
# 2236282                                                 92
# 857289                                                  62
# 1876455                                                 78
# 2037551                                                 15
# 1823206                                                 69
#
#          article__unique_ratio  article__unique_ratio_last30days  \
# 498353                0.790039                          0.790039
# 231479                0.904785                          0.852051
# 442966                0.908203                          0.908203
# 578545                0.884766                          0.884766
# 661618                0.945312                          0.945312
# ...                        ...                               ...
# 2236282               0.909668                          0.909668
# 857289                0.880859                          0.886230
# 1876455               0.797852                          0.799316
# 1876455                         1.093750
# 2037551                         1.093750
# 1823206                         1.093750
#
#          customer__num_days_from_first_purchase  \
# 498353                                    345.0
# 231479                                    345.0
# 442966                                    345.0
# 578545                                    345.0
# 661618                                    345.0
# ...                                         ...
# 2236282                                   716.0
# 857289                                    716.0
# 1876455                                   716.0
# 2037551                                   716.0
# 1823206                                   716.0
#
#          customer__num_days_from_last_purchase  \
# 498353                                     3.0
# 231479                                     3.0
# 442966                                     3.0
# 578545                                     3.0
# 661618                                     3.0
# ...                                        ...
# 2236282                                  222.0
# 857289                                   222.0
# 1876455                                  222.0
# 2037551                                  222.0
# 1823206                                  222.0
#
#          customer__num_purchased_articles  \
# 498353                               63.0
# 231479                               63.0
# 442966                               63.0
# 578545                               63.0
# 661618                               63.0
# ...                                   ...
# 2236282                              32.0
# 857289                               32.0
# 1876455                              32.0
# 2037551                              32.0
# 1823206                              32.0
#
#          customer__num_unique_purchased_articles  \
# 498353                                      54.0
# 231479                                      54.0
# 442966                                      54.0
# 578545                                      54.0
# 661618                                      54.0
# ...                                          ...
# 2236282                                     28.0
# 857289                                      28.0
# 1876455                                     28.0
# 2037551                                     28.0
# 1823206                                     28.0
#
#          customer__num_purchased_articles_last90days  \
# 498353                                          48.0
# 231479                                          48.0
# 442966                                          48.0
# 578545                                          48.0
# 661618                                          48.0
# ...                                              ...
# 2236282                                          0.0
# 857289                                           0.0
# 1876455                                          0.0
# 2037551                                          0.0
# 1823206                                          0.0
#
#          customer__num_unique_purchased_articles_last90days  \
# 498353                                                43.0
# 231479                                                43.0
# 442966                                                43.0
# 578545                                                43.0
# 661618                                                43.0
# ...                                                    ...
# 2236282                                                0.0
# 857289                                                 0.0
# 1876455                                                0.0
# 2037551                                                0.0
# 1823206                                                0.0
#
#          customer__num_purchased_articles_last30days  \
# 498353                                          17.0
# 231479                                          17.0
# 442966                                          17.0
# 578545                                          17.0
# 661618                                          17.0
# ...                                              ...
# 2236282                                          0.0
# 857289                                           0.0
# 1876455                                          0.0
# 2037551                                          0.0
# 1823206                                          0.0
#
#          customer__num_unique_purchased_articles_last30days  \
# 498353                                                14.0
# 231479                                                14.0
# 442966                                                14.0
# 578545                                                14.0
# 661618                                                14.0
# ...                                                    ...
# 2236282                                                0.0
# 857289                                                 0.0
# 1876455                                                0.0
# 2037551                                                0.0
# 1823206                                                0.0
#
#          customer__num_purchased_articles_last7days  \
# 498353                                         10.0
# 231479                                         10.0
# 442966                                         10.0
# 578545                                         10.0
# 661618                                         10.0
# ...                                             ...
# 2236282                                         0.0
# 857289                                          0.0
# 1876455                                         0.0
# 2037551                                         0.0
# 1823206                                         0.0
#
#          customer__num_unique_purchased_articles_last7days  \
# 498353                                                 7.0
# 231479                                                 7.0
# 442966                                                 7.0
# 578545                                                 7.0
# 661618                                                 7.0
# ...                                                    ...
# 2236282                                                0.0
# 857289                                                 0.0
# 1876455                                                0.0
# 2037551                                                0.0
# 1823206                                                0.0
#
#          customer__unique_ratio  customer__unique_ratio_last30days  \
# 498353                 0.856934                            0.82373
# 231479                 0.856934                            0.82373
# 442966                 0.856934                            0.82373
# 578545                 0.856934                            0.82373
# 661618                 0.856934                            0.82373
# ...                         ...                                ...
# 2236282                0.875000                            0.00000
# 857289                 0.875000                            0.00000
# 1876455                0.875000                            0.00000
# 2037551                0.875000                            0.00000
# 1823206                0.875000                            0.00000
#
#          customer__unique_ratio_last7days  \
# 498353                           0.700195
# 231479                           0.700195
# 442966                           0.700195
# 578545                           0.700195
# 661618                           0.700195
# ...                                   ...
# 2236282                          0.000000
# 857289                           0.000000
# 1876455                          0.000000
# 2037551                          0.000000
# 1823206                          0.000000
#
#          customer_article__num_days_from_last_purchase  \
# 498353                                               6
# 231479                                               3
# 442966                                               3
# 578545                                               6
# 661618                                               6
# ...                                                ...
# 2236282                                             -1
# 857289                                              -1
# 1876455                                             -1
# 2037551                                             -1
# 1823206                                             -1
#
#          customer_article__num_purchased  \
# 498353                                 2
# 231479                                 2
# 442966                                 2
# 578545                                 1
# 661618                                 1
# ...                                  ...
# 2236282                                0
# 857289                                 0
# 1876455                                0
# 2037551                                0
# 1823206                                0
#
#          customer_article__num_purchased_last90days  \
# 498353                                            2
# 231479                                            2
# 442966                                            2
# 578545                                            1
# 661618                                            1
# ...                                             ...
# 2236282                                           0
# 857289                                            0
# 1876455                                           0
# 2037551                                           0
# 1823206                                           0
#
#          customer_article__num_purchased_last30days  \
# 498353                                            2
# 231479                                            2
# 442966                                            2
# 578545                                            1
# 661618                                            1
# ...                                             ...
# 2236282                                           0
# 857289                                            0
# 1876455                                           0
# 2037551                                           0
# 1823206                                           0
#
#          customer_article__num_purchased_last7days  label   predict
# 498353                                           2    0.0  1.580528
# 231479                                           2    0.0  1.412874
# 442966                                           2    0.0  1.272221
# 578545                                           1    0.0  1.231387
# 661618                                           1    0.0  1.029473
# ...                                            ...    ...       ...
# 2236282                                          0    0.0 -0.343391
# 857289                                           0    0.0 -0.361437
# 1876455                                          0    0.0 -0.368458
# 2037551                                          0    0.0 -0.372589
# 1823206                                          0    0.0 -0.425626
#
# [827808 rows x 126 columns]

# %%
mapk(
    labels.groupby(['customer_id'])['article_id'].apply(list).tolist(),
    df_test.groupby(['customer_id'])['article_id'].apply(list).tolist(),
)
# Out:
# 0.031625322037571076

# %%
0.031303033532957845

ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    eval_at=12,
    boosting_type="gbdt", #gbdt #goss
    
    force_col_wise=True,
    num_leaves=40, #31 #40
    max_depth=10, #10 #-1
    learning_rate=0.1, #0.1
    
    reg_lambda=0, #0 #0.3
    
    importance_type='split',
    
    min_split_gain=0, #0 #0.7
    
    colsample_bytree=1, #1
    
    n_estimators=100, #100 #150
    
    random_state=42,
    verbose=1
)

# %%
0.0311 w/o fillna

ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    eval_at=12,
    boosting_type="gbdt", #gbdt #goss
    
    force_col_wise=True,
    num_leaves=31, #31 #40
    max_depth=-1, #10 #-1
    learning_rate=0.1, #0.1
    
    reg_lambda=0, #0 #0.3
    
    importance_type='gain',
    
    min_split_gain=0, #0 #0.7
    
    colsample_bytree=1, #1
    
    n_estimators=100, #100 #150
    
    random_state=42,
    verbose=1
)

# %%
0.03179736094980154, w/o fillna

ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    eval_at=12,
    boosting_type="gbdt", #gbdt #goss
    
    force_col_wise=True,
    num_leaves=31, #31 #40
    max_depth=-1, #10 #-1
    learning_rate=0.1, #0.1
    
    reg_lambda=0, #0 #0.3
    
    importance_type='split',
    
    min_split_gain=0, #0 #0.7
    
    colsample_bytree=1, #1
    
    n_estimators=100, #100 #150
    
    random_state=42,
    verbose=1
)

# %%
0.03212297695843095

ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    eval_at=12,
    boosting_type="gbdt", #gbdt #goss
    
    force_col_wise=True,
    num_leaves=31, #31 #40
    max_depth=-1, #10 #-1
    learning_rate=0.1, #0.1
    
    reg_lambda=0, #0 #0.3
    
    importance_type='split',
    
    min_split_gain=0, #0 #0.7
    
    colsample_bytree=1, #1
    
    n_estimators=150, #100 #150
    
    random_state=42,
    verbose=1
)

# %%
0.03216523246745132

ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    eval_at=12,
    boosting_type="gbdt", #gbdt #goss
    
    force_col_wise=True,
    num_leaves=40, #31 #40
    max_depth=-1, #10 #-1
    learning_rate=0.1, #0.1
    
    reg_lambda=0, #0 #0.3
    
    importance_type='split',
    
    min_split_gain=0, #0 #0.7
    
    colsample_bytree=1, #1
    
    n_estimators=200, #100 #150
    
    random_state=42,
    verbose=1
)

# %%
0.03216971818356945

ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    eval_at=12,
    boosting_type="gbdt", #gbdt #goss
    
    force_col_wise=True,
    num_leaves=40, #31 #40
    max_depth=-1, #10 #-1
    learning_rate=0.1, #0.1
    
#     reg_lambda=0.1, #0 #0.3
    
    importance_type='split',
    
    min_split_gain=0, #0 #0.7
    
    colsample_bytree=1, #1
    
    n_estimators=200, #100 #150
    
    random_state=42,
    verbose=1
)
